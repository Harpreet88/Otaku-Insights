# %%
import requests
import json
import time

# Base URL for ranking and anime detail
BASE_URL =
ANIME_DETAIL_URL =

# Your Client ID
CLIENT_ID =

# Set the headers with your Client ID for authentication
headers = {
    'X-MAL-CLIENT-ID': CLIENT_ID
}

# Function to get anime details by ID
def get_anime_details(anime_id):
    try:
        url = f"{ANIME_DETAIL_URL}{anime_id}?fields=id,title,type,score,scored_by,status,episodes,start_date,end_date,genres,synopsis,main_picture,url,title_english,title_japanese,title_synonyms,demographics,studios,rating,source,rank,popularity,members,favorites"
        response = requests.get(url, headers=headers)
        anime_data = response.json()

        # Extract additional fields
        details = {
            'anime_id': anime_data['id'],
            'title': anime_data['title'],
            'type': anime_data.get('type', 'N/A'),
            'score': anime_data.get('score', 'N/A'),
            'scored_by': anime_data.get('scored_by', 'N/A'),
            'status': anime_data.get('status', 'N/A'),
            'episodes': anime_data.get('episodes', 'N/A'),
            'start_date': anime_data.get('start_date', 'N/A'),
            'end_date': anime_data.get('end_date', 'N/A'),
            'genres': [genre['name'] for genre in anime_data.get('genres', [])],
            'synopsis': anime_data.get('synopsis', 'N/A'),
            'main_picture': anime_data['main_picture']['large'] if 'main_picture' in anime_data else 'N/A',
            'url': anime_data.get('url', 'N/A'),
            'title_english': anime_data.get('title_english', 'N/A'),
            'title_japanese': anime_data.get('title_japanese', 'N/A'),
            'title_synonyms': anime_data.get('title_synonyms', []),
            'demographics': [demographic['name'] for demographic in anime_data.get('demographics', [])],
            'studios': [studio['name'] for studio in anime_data.get('studios', [])],
            'rating': anime_data.get('rating', 'N/A'),
            'source': anime_data.get('source', 'N/A'),
            'rank': anime_data.get('rank', 'N/A'),
            'popularity': anime_data.get('popularity', 'N/A'),
            'members': anime_data.get('members', 'N/A'),
            'favorites': anime_data.get('favorites', 'N/A'),
        }

        return details

    except Exception as e:
        print(f"Error fetching details for anime_id {anime_id}: {e}")
        return None

# Fetch ranking data
def fetch_anime_ranking():
    offset = 0
    limit = 5
    all_anime_data = []

    while True:
        params = {
            'offset': offset,
            'limit': limit
        }

        print(f"Fetching page {offset // limit + 1}...")

        response = requests.get(BASE_URL, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            print(f"Response status: {response.status_code}")
            print(f"Response text: {json.dumps(data, indent=2)}")

            # Loop through each anime in the response data and fetch more details
            for item in data['data']:
                anime_id = item['node']['id']
                anime_details = get_anime_details(anime_id)

                if anime_details:
                    # Filter anime by year 2024
                    start_date = anime_details.get('start_date', '')
                    if start_date and start_date.startswith('2024'):
                        all_anime_data.append(anime_details)

            # Check if there is a next page
            if 'next' in data['paging']:
                next_page_url = data['paging']['next']
                offset += limit  # Increase offset for the next page
                time.sleep(1)  # Be respectful to the API, add a small delay between requests
            else:
                break
        else:
            print(f"Error fetching data: {response.status_code}")
            break

    return all_anime_data

# Save the data to a JSON file
def save_to_json(data, filename='anime_data_2024.json'):
    with open(filename, 'w') as f:
        json.dump(data, f, indent=2)

# Main execution
anime_data = fetch_anime_ranking()

# Save fetched anime data
save_to_json(anime_data)
print(f"Anime data saved successfully!")
# Out:
# Streaming output truncated to the last 5000 lines.
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1634/124231.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1634/124231l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 648
#       }
#     },
#     {
#       "node": {
#         "id": 42923,
#         "title": "SK\u221e",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1549/119195.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1549/119195l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 649
#       }
#     },
#     {
#       "node": {
#         "id": 535,
#         "title": "Slayers Next",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1165/92536.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1165/92536l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 650
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=640&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=650&limit=5"
#   }
# }
# Fetching page 131...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 5681,
#         "title": "Summer Wars",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1593/116751.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1593/116751l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 651
#       }
#     },
#     {
#       "node": {
#         "id": 16049,
#         "title": "Toaru Kagaku no Railgun S",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/75610.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/7/75610l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 652
#       }
#     },
#     {
#       "node": {
#         "id": 53410,
#         "title": "Yuru Camp\u25b3 Season 3",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1178/142710.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1178/142710l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 653
#       }
#     },
#     {
#       "node": {
#         "id": 41781,
#         "title": "BanG Dream! Movie: Episode of Roselia - II: Song I Am.",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1246/115689.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1246/115689l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 654
#       }
#     },
#     {
#       "node": {
#         "id": 57066,
#         "title": "Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka V: Houjou no Megami-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1299/144738.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1299/144738l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 655
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=645&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=655&limit=5"
#   }
# }
# Fetching page 132...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 153,
#         "title": "Juuni Kokuki",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/50859.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/6/50859l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 656
#       }
#     },
#     {
#       "node": {
#         "id": 3783,
#         "title": "Kara no Kyoukai Movie 3: Tsuukaku Zanryuu",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/4/21735.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/4/21735l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 657
#       }
#     },
#     {
#       "node": {
#         "id": 50631,
#         "title": "Komi-san wa, Comyushou desu. 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1108/121157.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1108/121157l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 658
#       }
#     },
#     {
#       "node": {
#         "id": 14513,
#         "title": "Magi: The Labyrinth of Magic",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/42773.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/42773l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 659
#       }
#     },
#     {
#       "node": {
#         "id": 44235,
#         "title": "Pui Pui Molcar",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1484/119197.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1484/119197l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 660
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=650&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=660&limit=5"
#   }
# }
# Fetching page 133...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 1096,
#         "title": "Kidou Keisatsu Patlabor 2 the Movie",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/74764.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/6/74764l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 661
#       }
#     },
#     {
#       "node": {
#         "id": 81,
#         "title": "Kidou Senshi Gundam: Dai 08 MS Shoutai",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/75618.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/75618l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 662
#       }
#     },
#     {
#       "node": {
#         "id": 9963,
#         "title": "Meitantei Conan Movie 15: Chinmoku no Quarter",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/32035.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/32035l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 663
#       }
#     },
#     {
#       "node": {
#         "id": 20,
#         "title": "Naruto",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1141/142503.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1141/142503l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 664
#       }
#     },
#     {
#       "node": {
#         "id": 57554,
#         "title": "Rurouni Kenshin: Meiji Kenkaku Romantan - Kyoto Douran",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1314/145530.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1314/145530l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 665
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=655&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=665&limit=5"
#   }
# }
# Fetching page 134...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 1914,
#         "title": "Saiunkoku Monogatari 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1998/139962.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1998/139962l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 666
#       }
#     },
#     {
#       "node": {
#         "id": 6211,
#         "title": "Tokyo Magnitude 8.0",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/13776.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/10/13776l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 667
#       }
#     },
#     {
#       "node": {
#         "id": 5365,
#         "title": "Tsumiki no Ie",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1063/117013.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1063/117013l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 668
#       }
#     },
#     {
#       "node": {
#         "id": 14813,
#         "title": "Yahari Ore no Seishun Love Comedy wa Machigatteiru.",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1786/120117.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1786/120117l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 669
#       }
#     },
#     {
#       "node": {
#         "id": 27663,
#         "title": "Baby Steps 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/73683.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/73683l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 670
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=660&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=670&limit=5"
#   }
# }
# Fetching page 135...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 37870,
#         "title": "BanG Dream! 3rd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1985/104767.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1985/104767l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 671
#       }
#     },
#     {
#       "node": {
#         "id": 1482,
#         "title": "D.Gray-man",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/13/75194.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/13/75194l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 672
#       }
#     },
#     {
#       "node": {
#         "id": 2759,
#         "title": "Evangelion Movie 1: Jo",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/74975.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/74975l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 673
#       }
#     },
#     {
#       "node": {
#         "id": 6421,
#         "title": "Fullmetal Alchemist: Brotherhood Specials",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1493/91571.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1493/91571l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 674
#       }
#     },
#     {
#       "node": {
#         "id": 2563,
#         "title": "Aria the OVA: Arietta",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/77622.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/77622l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 675
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=665&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=675&limit=5"
#   }
# }
# Fetching page 136...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 48585,
#         "title": "Black Clover: Mahou Tei no Ken",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1337/136363.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1337/136363l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 676
#       }
#     },
#     {
#       "node": {
#         "id": 36456,
#         "title": "Boku no Hero Academia 3rd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1319/92084.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1319/92084l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 677
#       }
#     },
#     {
#       "node": {
#         "id": 2167,
#         "title": "Clannad",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1804/95033.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1804/95033l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 678
#       }
#     },
#     {
#       "node": {
#         "id": 3167,
#         "title": "Eve no Jikan",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/13/19480.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/13/19480l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 679
#       }
#     },
#     {
#       "node": {
#         "id": 7054,
#         "title": "Kaichou wa Maid-sama!",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/25254.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/6/25254l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 680
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=670&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=680&limit=5"
#   }
# }
# Fetching page 137...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 14807,
#         "title": "Kara no Kyoukai Movie: Mirai Fukuin",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/56621.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/6/56621l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 681
#       }
#     },
#     {
#       "node": {
#         "id": 82,
#         "title": "Kidou Senshi Gundam 0080: Pocket no Naka no Sensou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1/82.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1/82l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 682
#       }
#     },
#     {
#       "node": {
#         "id": 40174,
#         "title": "Zombieland Saga Revenge",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1118/115156.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1118/115156l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 683
#       }
#     },
#     {
#       "node": {
#         "id": 846,
#         "title": "School Rumble Ni Gakki",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/5/75490.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/5/75490l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 684
#       }
#     },
#     {
#       "node": {
#         "id": 35788,
#         "title": "Shokugeki no Souma: San no Sara",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/88434.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/88434l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 685
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=675&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=685&limit=5"
#   }
# }
# Fetching page 138...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 1065,
#         "title": "Touch",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/53087.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/3/53087l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 686
#       }
#     },
#     {
#       "node": {
#         "id": 1023,
#         "title": "Wolf's Rain OVA",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1091/134883.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1091/134883l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 687
#       }
#     },
#     {
#       "node": {
#         "id": 35382,
#         "title": "Yuri!!! on Ice: Yuri Plisetsky GPF in Barcelona EX - Welcome to The Madness",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/85548.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/6/85548l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 688
#       }
#     },
#     {
#       "node": {
#         "id": 42250,
#         "title": "Bungou Stray Dogs Wan!",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1293/111430.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1293/111430l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 689
#       }
#     },
#     {
#       "node": {
#         "id": 223,
#         "title": "Dragon Ball",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1887/92364.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1887/92364l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 690
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=680&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=690&limit=5"
#   }
# }
# Fetching page 139...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 4789,
#         "title": "ef: A Tale of Melodies.",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1675/131993.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1675/131993l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 691
#       }
#     },
#     {
#       "node": {
#         "id": 16,
#         "title": "Hachimitsu to Clover",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1301/133577.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1301/133577l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 692
#       }
#     },
#     {
#       "node": {
#         "id": 387,
#         "title": "Haibane Renmei",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/13134.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/13134l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 693
#       }
#     },
#     {
#       "node": {
#         "id": 2004,
#         "title": "Hanada Shounen-shi",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/87319.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/87319l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 694
#       }
#     },
#     {
#       "node": {
#         "id": 39468,
#         "title": "Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1582/101697.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1582/101697l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 695
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=685&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=695&limit=5"
#   }
# }
# Fetching page 140...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 53924,
#         "title": "Jibaku Shounen Hanako-kun 2",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1878/146291.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1878/146291l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 696
#       }
#     },
#     {
#       "node": {
#         "id": 16706,
#         "title": "Kami nomi zo Shiru Sekai: Megami-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/6/51949.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/6/51949l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 697
#       }
#     },
#     {
#       "node": {
#         "id": 9656,
#         "title": "Kimi ni Todoke 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1311/121574.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1311/121574l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 698
#       }
#     },
#     {
#       "node": {
#         "id": 2448,
#         "title": "Koukaku Kidoutai: Stand Alone Complex 2nd GIG - Individual Eleven",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/5/2829.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/5/2829l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 699
#       }
#     },
#     {
#       "node": {
#         "id": 6171,
#         "title": "Saint Seiya: The Lost Canvas - Meiou Shinwa",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/8/75546.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/8/75546l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 700
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=690&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=700&limit=5"
#   }
# }
# Fetching page 141...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 40716,
#         "title": "Kakushigoto",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1048/128385.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1048/128385l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 701
#       }
#     },
#     {
#       "node": {
#         "id": 41611,
#         "title": "Wan Sheng Jie",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1854/106930.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1854/106930l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 702
#       }
#     },
#     {
#       "node": {
#         "id": 861,
#         "title": "xxxHOLiC",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/5/21858.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/5/21858l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 703
#       }
#     },
#     {
#       "node": {
#         "id": 31173,
#         "title": "Akagami no Shirayuki-hime 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/77834.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/77834l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 704
#       }
#     },
#     {
#       "node": {
#         "id": 34440,
#         "title": "Code Geass: Hangyaku no Lelouch III - Oudou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1126/91344.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1126/91344l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 705
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=695&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=705&limit=5"
#   }
# }
# Fetching page 142...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 23199,
#         "title": "Durarara!!x2 Shou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/67743.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/67743l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 706
#       }
#     },
#     {
#       "node": {
#         "id": 36963,
#         "title": "IDOLiSH7 Vibrato",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1131/90676.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1131/90676l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 707
#       }
#     },
#     {
#       "node": {
#         "id": 54915,
#         "title": "5-toubun no Hanayome\u223d",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1567/135752.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1567/135752l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 708
#       }
#     },
#     {
#       "node": {
#         "id": 48411,
#         "title": "Aria the Benedizione",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1707/117069.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1707/117069l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 709
#       }
#     },
#     {
#       "node": {
#         "id": 49469,
#         "title": "Beastars Final Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1699/142187.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1699/142187l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 710
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=700&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=710&limit=5"
#   }
# }
# Error fetching details for anime_id 36963: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 54915: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 48411: Expecting value: line 1 column 1 (char 0)
# Fetching page 143...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 59077,
#         "title": "Benghuai: Xing Qiong Tiedao - Gelamo de Yujin",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1367/143582.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1367/143582l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 711
#       }
#     },
#     {
#       "node": {
#         "id": 269,
#         "title": "Bleach",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/40451.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/40451l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 712
#       }
#     },
#     {
#       "node": {
#         "id": 27831,
#         "title": "Durarara!!x2 Ten",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/8/74981.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/8/74981l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 713
#       }
#     },
#     {
#       "node": {
#         "id": 7465,
#         "title": "Eve no Jikan (Movie)",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/27711.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/27711l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 714
#       }
#     },
#     {
#       "node": {
#         "id": 51318,
#         "title": "Hanma Baki: Son of Ogre 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1800/135847.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1800/135847l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 715
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=705&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=715&limit=5"
#   }
# }
# Fetching page 144...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 967,
#         "title": "Hokuto no Ken",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/8/18502.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/8/18502l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 716
#       }
#     },
#     {
#       "node": {
#         "id": 9996,
#         "title": "Hyouge Mono",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/77282.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/77282l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 717
#       }
#     },
#     {
#       "node": {
#         "id": 4672,
#         "title": "Koukaku Kidoutai 2.0",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/75608.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/3/75608l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 718
#       }
#     },
#     {
#       "node": {
#         "id": 77,
#         "title": "Mahou Shoujo Lyrical Nanoha A's",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/4/6767.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/4/6767l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 719
#       }
#     },
#     {
#       "node": {
#         "id": 40397,
#         "title": "Maoujou de Oyasumi",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1448/108514.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1448/108514l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 720
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=710&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=720&limit=5"
#   }
# }
# Fetching page 145...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 7720,
#         "title": "Ookiku Furikabutte: Natsu no Taikai-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/18671.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/10/18671l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 721
#       }
#     },
#     {
#       "node": {
#         "id": 30015,
#         "title": "ReLIFE",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/82149.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/3/82149l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 722
#       }
#     },
#     {
#       "node": {
#         "id": 59497,
#         "title": "Rising Impact Season 2",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1161/144669.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1161/144669l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 723
#       }
#     },
#     {
#       "node": {
#         "id": 52865,
#         "title": "Romantic Killer",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1764/142001.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1764/142001l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 724
#       }
#     },
#     {
#       "node": {
#         "id": 401,
#         "title": "Rurouni Kenshin: Meiji Kenkaku Romantan - Seisou-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1971/90877.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1971/90877l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 725
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=715&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=725&limit=5"
#   }
# }
# Fetching page 146...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 32615,
#         "title": "Youjo Senki",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/5/82890.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/5/82890l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 726
#       }
#     },
#     {
#       "node": {
#         "id": 51180,
#         "title": "Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e 3rd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1332/139318.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1332/139318l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 727
#       }
#     },
#     {
#       "node": {
#         "id": 34376,
#         "title": "Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou 3 - Yakusoku",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/86984.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/86984l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 728
#       }
#     },
#     {
#       "node": {
#         "id": 42916,
#         "title": "Sword Art Online: Progressive Movie - Hoshi Naki Yoru no Aria",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1590/116274.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1590/116274l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 729
#       }
#     },
#     {
#       "node": {
#         "id": 4053,
#         "title": "Tennis no Oujisama: Zenkoku Taikai-hen - Final",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1142/133867.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1142/133867l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 730
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=720&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=730&limit=5"
#   }
# }
# Fetching page 147...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 543,
#         "title": "Vampire Hunter D (2000)",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1571/135153.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1571/135153l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 731
#       }
#     },
#     {
#       "node": {
#         "id": 25879,
#         "title": "Working!!!",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/73886.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/73886l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 732
#       }
#     },
#     {
#       "node": {
#         "id": 50346,
#         "title": "Yofukashi no Uta",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1045/123711.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1045/123711l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 733
#       }
#     },
#     {
#       "node": {
#         "id": 4772,
#         "title": "Aria the Origination: Sono Choppiri Himitsu no Basho ni...",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/15053.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/15053l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 734
#       }
#     },
#     {
#       "node": {
#         "id": 996,
#         "title": "Bishoujo Senshi Sailor Moon: Sailor Stars",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1645/105992.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1645/105992l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 735
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=725&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=735&limit=5"
#   }
# }
# Fetching page 148...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 2890,
#         "title": "Gake no Ue no Ponyo",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1331/138727.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1331/138727l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 736
#       }
#     },
#     {
#       "node": {
#         "id": 33970,
#         "title": "Girls & Panzer: Saishuushou Part 1",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1859/91463.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1859/91463l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 737
#       }
#     },
#     {
#       "node": {
#         "id": 38422,
#         "title": "High Score Girl: Extra Stage",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1057/111384.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1057/111384l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 738
#       }
#     },
#     {
#       "node": {
#         "id": 416,
#         "title": "Kurenai no Buta",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1728/138709.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1728/138709l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 739
#       }
#     },
#     {
#       "node": {
#         "id": 5029,
#         "title": "Major Movie: Yuujou no Winning Shot",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/75221.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/10/75221l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 740
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=730&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=740&limit=5"
#   }
# }
# Fetching page 149...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 1530,
#         "title": "Kanon (2006)",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1362/128746.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1362/128746l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 741
#       }
#     },
#     {
#       "node": {
#         "id": 31973,
#         "title": "Kidou Senshi Gundam Thunderbolt",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/77176.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/77176l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 742
#       }
#     },
#     {
#       "node": {
#         "id": 33221,
#         "title": "Kidou Senshi Gundam Thunderbolt: December Sky",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/79823.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/79823l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 743
#       }
#     },
#     {
#       "node": {
#         "id": 2076,
#         "title": "Kindaichi Shounen no Jikenbo",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1702/120440.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1702/120440l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 744
#       }
#     },
#     {
#       "node": {
#         "id": 5678,
#         "title": "Kobato.",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/8/79838.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/8/79838l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 745
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=735&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=745&limit=5"
#   }
# }
# Fetching page 150...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 7222,
#         "title": "Macross F Movie 2: Sayonara no Tsubasa",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/13/76398.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/13/76398l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 746
#       }
#     },
#     {
#       "node": {
#         "id": 56785,
#         "title": "Meitantei Conan Movie 27: 100-man Dollar no Michishirube",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1888/141209.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1888/141209l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 747
#       }
#     },
#     {
#       "node": {
#         "id": 16067,
#         "title": "Nagi no Asu kara",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/53549.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/53549l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 748
#       }
#     },
#     {
#       "node": {
#         "id": 46422,
#         "title": "Niehime to Kemono no Ou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1397/133339.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1397/133339l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 749
#       }
#     },
#     {
#       "node": {
#         "id": 17549,
#         "title": "Non Non Biyori",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/51581.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/51581l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 750
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=740&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=750&limit=5"
#   }
# }
# Fetching page 151...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 20507,
#         "title": "Noragami",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1886/128266.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1886/128266l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 751
#       }
#     },
#     {
#       "node": {
#         "id": 12477,
#         "title": "Sakasama no Patema",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/52415.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/52415l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 752
#       }
#     },
#     {
#       "node": {
#         "id": 23777,
#         "title": "Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/72510.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/72510l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 753
#       }
#     },
#     {
#       "node": {
#         "id": 36949,
#         "title": "Shokugeki no Souma: San no Sara - Tootsuki Ressha-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1604/93531.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1604/93531l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 754
#       }
#     },
#     {
#       "node": {
#         "id": 2154,
#         "title": "Tekkon Kinkreet",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/8520.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/8520l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 755
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=745&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=755&limit=5"
#   }
# }
# Fetching page 152...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 38349,
#         "title": "Wotaku ni Koi wa Muzukashii OVA",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1892/111383.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1892/111383l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 756
#       }
#     },
#     {
#       "node": {
#         "id": 41923,
#         "title": "Yi Nian Yong Heng",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1712/108161.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1712/108161l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 757
#       }
#     },
#     {
#       "node": {
#         "id": 39565,
#         "title": "Boku no Hero Academia the Movie 2: Heroes:Rising",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1019/103292.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1019/103292l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 758
#       }
#     },
#     {
#       "node": {
#         "id": 38084,
#         "title": "Fate/Grand Order: Zettai Majuu Sensen Babylonia",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1194/103420.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1194/103420l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 759
#       }
#     },
#     {
#       "node": {
#         "id": 39570,
#         "title": "High Score Girl II",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1560/99904.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1560/99904l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 760
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=750&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=760&limit=5"
#   }
# }
# Fetching page 153...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 55310,
#         "title": "Atarashii Joushi wa Do Tennen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1630/138388.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1630/138388l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 761
#       }
#     },
#     {
#       "node": {
#         "id": 4059,
#         "title": "Clannad: Mou Hitotsu no Sekai, Tomoyo-hen",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/19620.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/19620l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 762
#       }
#     },
#     {
#       "node": {
#         "id": 58883,
#         "title": "Dead Dead Demons Dededede Destruction (OVA)",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1528/143212.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1528/143212l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 763
#       }
#     },
#     {
#       "node": {
#         "id": 37150,
#         "title": "Douluo Dalu",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1438/101531.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1438/101531l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 764
#       }
#     },
#     {
#       "node": {
#         "id": 122,
#         "title": "Full Moon wo Sagashite",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1900/99154.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1900/99154l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 765
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=755&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=765&limit=5"
#   }
# }
# Fetching page 154...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 11239,
#         "title": "Hidamari Sketch x Honeycomb",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/50501.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/50501l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 766
#       }
#     },
#     {
#       "node": {
#         "id": 645,
#         "title": "Hikaru no Go: Hokuto Hai e no Michi",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/78453.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/78453l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 767
#       }
#     },
#     {
#       "node": {
#         "id": 38080,
#         "title": "Kono Oto Tomare!",
# ...
#         "id": 9513,
#         "title": "Beelzebub",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/28013.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/28013l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 941
#       }
#     },
#     {
#       "node": {
#         "id": 31964,
#         "title": "Boku no Hero Academia",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/78745.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/10/78745l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 942
#       }
#     },
#     {
#       "node": {
#         "id": 52505,
#         "title": "Dark Gathering",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1346/138731.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1346/138731l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 943
#       }
#     },
#     {
#       "node": {
#         "id": 8408,
#         "title": "Durarara!! Specials",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/4/28684.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/4/28684l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 944
#       }
#     },
#     {
#       "node": {
#         "id": 24471,
#         "title": "Hoozuki no Reitetsu OVA",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1531/138993.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1531/138993l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 945
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=935&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=945&limit=5"
#   }
# }
# Fetching page 190...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 429,
#         "title": "Kaleido Star: Legend of Phoenix - Layla Hamilton Monogatari",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/28863.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/28863l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 946
#       }
#     },
#     {
#       "node": {
#         "id": 50403,
#         "title": "Liang Bu Yi 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1385/119524.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1385/119524l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 947
#       }
#     },
#     {
#       "node": {
#         "id": 31741,
#         "title": "Magi: Sinbad no Bouken (TV)",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/78783.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/10/78783l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 948
#       }
#     },
#     {
#       "node": {
#         "id": 569,
#         "title": "Musekinin Kanchou Tylor",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/4/14898.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/4/14898l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 949
#       }
#     },
#     {
#       "node": {
#         "id": 30885,
#         "title": "Noragami Aragoto OVA",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/77510.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/77510l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 950
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=940&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=950&limit=5"
#   }
# }
# Fetching page 191...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 25161,
#         "title": "One Piece 3D2Y: Ace no shi wo Koete! Luffy Nakama Tono Chikai",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/3/64755.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/3/64755l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 951
#       }
#     },
#     {
#       "node": {
#         "id": 36796,
#         "title": "Owarimonogatari 2nd Season Recaps",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/88962.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/88962l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 952
#       }
#     },
#     {
#       "node": {
#         "id": 20371,
#         "title": "Sekaiichi Hatsukoi Movie: Yokozawa Takafumi no Baai",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/65927.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/65927l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 953
#       }
#     },
#     {
#       "node": {
#         "id": 8063,
#         "title": "Sekaiichi Hatsukoi OVA",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/11/35863.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/11/35863l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 954
#       }
#     },
#     {
#       "node": {
#         "id": 49889,
#         "title": "Tsuki ga Michibiku Isekai Douchuu 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1794/142621.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1794/142621l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 955
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=945&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=955&limit=5"
#   }
# }
# Fetching page 192...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 59939,
#         "title": "Tunshi Xingkong Movie: Xueluo Dalu",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1695/145740.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1695/145740l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 956
#       }
#     },
#     {
#       "node": {
#         "id": 1921,
#         "title": "Urusei Yatsura 2: Beautiful Dreamer",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1999/98665.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1999/98665l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 957
#       }
#     },
#     {
#       "node": {
#         "id": 6586,
#         "title": "Yume-iro P\u00e2tissi\u00e8re",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1076/134431.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1076/134431l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 958
#       }
#     },
#     {
#       "node": {
#         "id": 400,
#         "title": "Seihou Bukyou Outlaw Star",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1868/145122.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1868/145122l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 959
#       }
#     },
#     {
#       "node": {
#         "id": 6582,
#         "title": "Tentai Senshi Sunred 2nd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/15051.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/15051l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 960
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=950&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=960&limit=5"
#   }
# }
# Fetching page 193...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 9941,
#         "title": "Tiger & Bunny",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/13/29466.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/13/29466l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 961
#       }
#     },
#     {
#       "node": {
#         "id": 52093,
#         "title": "Trigun Stampede",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1426/129194.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1426/129194l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 962
#       }
#     },
#     {
#       "node": {
#         "id": 6505,
#         "title": "Tteotda Keunyeo!!",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/2/29995.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/2/29995l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 963
#       }
#     },
#     {
#       "node": {
#         "id": 40615,
#         "title": "Umibe no \u00c9tranger",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1668/108792.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1668/108792l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 964
#       }
#     },
#     {
#       "node": {
#         "id": 890,
#         "title": "Yuusha-Ou GaoGaiGar",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/12/21183.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/12/21183l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 965
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=955&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=965&limit=5"
#   }
# }
# Fetching page 194...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 32998,
#         "title": "91 Days",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/13/80515.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/13/80515l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 966
#       }
#     },
#     {
#       "node": {
#         "id": 15039,
#         "title": "Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. Movie",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/5/49993.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/5/49993l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 967
#       }
#     },
#     {
#       "node": {
#         "id": 40262,
#         "title": "Haikyuu!! Riku vs. Kuu",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1527/102671.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1527/102671l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 968
#       }
#     },
#     {
#       "node": {
#         "id": 14175,
#         "title": "Hanasaku Iroha Movie: Home Sweet Home",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/70701.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/70701l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 969
#       }
#     },
#     {
#       "node": {
#         "id": 3604,
#         "title": "Hidamari Sketch x 365",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1571/134092.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1571/134092l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 970
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=960&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=970&limit=5"
#   }
# }
# Fetching page 195...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 39534,
#         "title": "Jibaku Shounen Hanako-kun",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1050/111687.webp",
#           "large": "https://cdn.myanimelist.net/images/anime/1050/111687l.webp"
#         }
#       },
#       "ranking": {
#         "rank": 971
#       }
#     },
#     {
#       "node": {
#         "id": 48926,
#         "title": "Komi-san wa, Comyushou desu.",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1899/117237.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1899/117237l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 972
#       }
#     },
#     {
#       "node": {
#         "id": 32380,
#         "title": "Kono Subarashii Sekai ni Shukufuku wo!: Kono Subarashii Choker ni Shukufuku wo!",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1649/98516.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1649/98516l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 973
#       }
#     },
#     {
#       "node": {
#         "id": 4087,
#         "title": "Michiko to Hatchin",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/10/59535.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/10/59535l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 974
#       }
#     },
#     {
#       "node": {
#         "id": 50739,
#         "title": "Otonari no Tenshi-sama ni Itsunomanika Dame Ningen ni Sareteita Ken",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1240/133638.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1240/133638l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 975
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=965&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=975&limit=5"
#   }
# }
# Fetching page 196...
# Response status: 200
# Response text: {
#   "data": [
#     {
#       "node": {
#         "id": 4280,
#         "title": "Kara no Kyoukai Movie 4: Garan no Dou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/9/21736.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/9/21736l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 976
#       }
#     },
#     {
#       "node": {
#         "id": 37765,
#         "title": "Kidou Senshi Gundam: Senkou no Hathaway",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1195/115685.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1195/115685l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 977
#       }
#     },
#     {
#       "node": {
#         "id": 32871,
#         "title": "Kuroko no Basket Movie 3: Winter Cup - Tobira no Mukou",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/7/80729.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/7/80729l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 978
#       }
#     },
#     {
#       "node": {
#         "id": 54764,
#         "title": "Madogiwa no Totto-chan",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1001/139067.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1001/139067l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 979
#       }
#     },
#     {
#       "node": {
#         "id": 49784,
#         "title": "Mairimashita! Iruma-kun 3rd Season",
#         "main_picture": {
#           "medium": "https://cdn.myanimelist.net/images/anime/1688/128720.jpg",
#           "large": "https://cdn.myanimelist.net/images/anime/1688/128720l.jpg"
#         }
#       },
#       "ranking": {
#         "rank": 980
#       }
#     }
#   ],
#   "paging": {
#     "previous": "https://api.myanimelist.net/v2/anime/ranking?offset=970&limit=5",
#     "next": "https://api.myanimelist.net/v2/anime/ranking?offset=980&limit=5"
#   }
# }
# Fetching page 197...
# Error fetching data: 504
# Anime data saved successfully!

# %%
# now convert this json file to csv

import json
import csv

# Step 1: Load the JSON file
with open('anime_data_2024.json', 'r', encoding='utf-8') as json_file:
    anime_data = json.load(json_file)

# Step 2: Define the CSV file name
csv_file_name = 'anime_data_2024.csv'

# Step 3: Convert JSON to CSV
with open(csv_file_name, 'w', newline='', encoding='utf-8') as csv_file:
    # Create a CSV writer object
    writer = csv.writer(csv_file)

    # Write the header (column names)
    header = [
        "anime_id", "title", "type", "score", "scored_by", "status", "episodes",
        "start_date", "end_date", "genres", "synopsis", "main_picture", "url",
        "title_english", "title_japanese", "title_synonyms", "demographics",
        "studios", "rating", "source", "rank", "popularity", "members", "favorites"
    ]
    writer.writerow(header)

    # Write the data rows
    for anime in anime_data:
        writer.writerow([
            anime["anime_id"],
            anime["title"],
            anime["type"],
            anime["score"],
            anime["scored_by"],
            anime["status"],
            anime["episodes"],
            anime["start_date"],
            anime["end_date"],
            ", ".join(anime["genres"]),  # Flatten genres list into a string
            anime["synopsis"],
            anime["main_picture"],
            anime["url"],
            anime["title_english"],
            anime["title_japanese"],
            ", ".join(anime["title_synonyms"]),  # Flatten title_synonyms list
            ", ".join(anime["demographics"]),    # Flatten demographics list
            ", ".join(anime["studios"]),         # Flatten studios list
            anime["rating"],
            anime["source"],
            anime["rank"],
            anime["popularity"],
            anime["members"],
            anime["favorites"]
        ])

print(f"CSV file '{csv_file_name}' has been created successfully!")
# Out:
# CSV file 'anime_data_2024.csv' has been created successfully!

# %%
# lets do it for 2015- 2025
import requests
import json
import time

# Base URL for ranking and anime detail
BASE_URL = "https://api.myanimelist.net/v2/anime/ranking"
ANIME_DETAIL_URL = "https://api.myanimelist.net/v2/anime/"

# Your Client ID
CLIENT_ID = 'b0e49cf1fc5cf5653de57077bae8b2af'

# Set the headers with your Client ID for authentication
headers = {
    'X-MAL-CLIENT-ID': CLIENT_ID
}

# Function to get anime details by ID
def get_anime_details(anime_id):
    try:
        url = f"{ANIME_DETAIL_URL}{anime_id}?fields=id,title,type,score,scored_by,status,episodes,start_date,end_date,genres,synopsis,main_picture,url,title_english,title_japanese,title_synonyms,demographics,studios,rating,source,rank,popularity,members,favorites"
        response = requests.get(url, headers=headers)
        anime_data = response.json()

        # Extract additional fields
        details = {
            'anime_id': anime_data['id'],
            'title': anime_data['title'],
            'type': anime_data.get('type', 'N/A'),
            'score': anime_data.get('score', 'N/A'),
            'scored_by': anime_data.get('scored_by', 'N/A'),
            'status': anime_data.get('status', 'N/A'),
            'episodes': anime_data.get('episodes', 'N/A'),
            'start_date': anime_data.get('start_date', 'N/A'),
            'end_date': anime_data.get('end_date', 'N/A'),
            'genres': [genre['name'] for genre in anime_data.get('genres', [])],
            'synopsis': anime_data.get('synopsis', 'N/A'),
            'main_picture': anime_data['main_picture']['large'] if 'main_picture' in anime_data else 'N/A',
            'url': anime_data.get('url', 'N/A'),
            'title_english': anime_data.get('title_english', 'N/A'),
            'title_japanese': anime_data.get('title_japanese', 'N/A'),
            'title_synonyms': anime_data.get('title_synonyms', []),
            'demographics': [demographic['name'] for demographic in anime_data.get('demographics', [])],
            'studios': [studio['name'] for studio in anime_data.get('studios', [])],
            'rating': anime_data.get('rating', 'N/A'),
            'source': anime_data.get('source', 'N/A'),
            'rank': anime_data.get('rank', 'N/A'),
            'popularity': anime_data.get('popularity', 'N/A'),
            'members': anime_data.get('members', 'N/A'),
            'favorites': anime_data.get('favorites', 'N/A'),
        }

        return details

    except Exception as e:
        print(f"Error fetching details for anime_id {anime_id}: {e}")
        return None

# Fetch ranking data
def fetch_anime_ranking():
    offset = 0
    limit = 100  # Maximum results per request
    all_anime_data = []

    while True:
        params = {
            'offset': offset,
            'limit': limit
        }

        print(f"Fetching page {offset // limit + 1}...")

        response = requests.get(BASE_URL, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            print(f"Response status: {response.status_code}")

            # Loop through each anime in the response data and fetch more details
            for item in data['data']:
                anime_id = item['node']['id']
                anime_details = get_anime_details(anime_id)

                if anime_details:
                    # Filter anime by year (2015 to 2025)
                    start_date = anime_details.get('start_date', '')
                    if start_date:
                        year = int(start_date.split('-')[0])  # Extract year from start_date
                        if 2015 <= year <= 2025:  # Only include anime from 2015 to 2025
                            all_anime_data.append(anime_details)

            # Check if there is a next page
            if 'paging' in data and 'next' in data['paging']:
                offset += limit  # Increase offset for the next page
                time.sleep(1)  # Add a small delay between requests to respect rate limits
            else:
                print("No more pages available.")
                break
        else:
            print(f"Error fetching data: {response.status_code}")
            break

    return all_anime_data

# Save the data to a JSON file
def save_to_json(data, filename='anime_data_2015_2025.json'):
    with open(filename, 'w') as f:
        json.dump(data, f, indent=2)

# Main execution
anime_data = fetch_anime_ranking()

# Save fetched anime data
save_to_json(anime_data)
print(f"Anime data saved successfully! Total rows: {len(anime_data)}")
# Out:
# Fetching page 1...
# Response status: 200
# Fetching page 2...
# Response status: 200
# Error fetching details for anime_id 36538: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 36885: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 48561: Expecting value: line 1 column 1 (char 0)
# Fetching page 3...
# Response status: 200
# Fetching page 4...
# Response status: 200
# Error fetching details for anime_id 55866: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 53393: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 16664: Expecting value: line 1 column 1 (char 0)
# Fetching page 5...
# Response status: 200
# Fetching page 6...
# Response status: 200
# Error fetching details for anime_id 302: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 3702: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 6746: Expecting value: line 1 column 1 (char 0)
# Fetching page 7...
# Response status: 200
# Fetching page 8...
# Response status: 200
# Error fetching details for anime_id 51180: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 34376: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 42916: Expecting value: line 1 column 1 (char 0)
# Fetching page 9...
# Response status: 200
# Error fetching details for anime_id 49570: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 37936: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 6377: Expecting value: line 1 column 1 (char 0)
# Fetching page 10...
# Response status: 200
# Fetching page 11...
# Response status: 200
# Error fetching details for anime_id 875: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 8038: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 15771: Expecting value: line 1 column 1 (char 0)
# Fetching page 12...
# Response status: 200
# Fetching page 13...
# Response status: 200
# Error fetching details for anime_id 50273: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 51533: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 23249: Expecting value: line 1 column 1 (char 0)
# Fetching page 14...
# Response status: 200
# Fetching page 15...
# Response status: 200
# Error fetching details for anime_id 39071: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 54722: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 2963: Expecting value: line 1 column 1 (char 0)
# Fetching page 16...
# Response status: 200
# Fetching page 17...
# Response status: 200
# Error fetching details for anime_id 58448: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 55684: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 58555: Expecting value: line 1 column 1 (char 0)
# Fetching page 18...
# Response status: 200
# Error fetching details for anime_id 39555: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 1240: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 54865: Expecting value: line 1 column 1 (char 0)
# Fetching page 19...
# Response status: 200
# Fetching page 20...
# Response status: 200
# Error fetching details for anime_id 914: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 666: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 53879: Expecting value: line 1 column 1 (char 0)
# Fetching page 21...
# Response status: 200
# Fetching page 22...
# Response status: 200
# Error fetching details for anime_id 435: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 32900: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 38555: Expecting value: line 1 column 1 (char 0)
# Fetching page 23...
# Response status: 200
# Fetching page 24...
# Response status: 200
# Error fetching details for anime_id 364: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 25183: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 242: Expecting value: line 1 column 1 (char 0)
# Fetching page 25...
# Response status: 200
# Fetching page 26...
# Response status: 200
# Error fetching details for anime_id 41587: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 42519: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 35756: Expecting value: line 1 column 1 (char 0)
# Fetching page 27...
# Response status: 200
# Error fetching details for anime_id 207: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 50094: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 40496: Expecting value: line 1 column 1 (char 0)
# Fetching page 28...
# Response status: 200
# Fetching page 29...
# Response status: 200
# Error fetching details for anime_id 34086: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 1146: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 1303: Expecting value: line 1 column 1 (char 0)
# Fetching page 30...
# Response status: 200
# Fetching page 31...
# Response status: 200
# Error fetching details for anime_id 30901: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 52765: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 37993: Expecting value: line 1 column 1 (char 0)
# Fetching page 32...
# Response status: 200
# Error fetching details for anime_id 485: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 39026: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 1250: Expecting value: line 1 column 1 (char 0)
# Fetching page 33...
# Response status: 200
# Fetching page 34...
# Response status: 200
# Error fetching details for anime_id 6198: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 2948: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 13409: Expecting value: line 1 column 1 (char 0)
# Fetching page 35...
# Response status: 200
# Fetching page 36...
# Response status: 200
# Error fetching details for anime_id 192: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 3345: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 2834: Expecting value: line 1 column 1 (char 0)
# Fetching page 37...
# Response status: 200
# Fetching page 38...
# Response status: 200
# Error fetching details for anime_id 19653: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 16468: Expecting value: line 1 column 1 (char 0)
# Fetching page 39...
# Response status: 200
# Error fetching details for anime_id 53263: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 44411: Expecting value: line 1 column 1 (char 0)
# Fetching page 40...
# Response status: 200
# Error fetching details for anime_id 34325: Expecting value: line 1 column 1 (char 0)
# Fetching page 41...
# Response status: 200
# Error fetching details for anime_id 50562: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 32887: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 5658: Expecting value: line 1 column 1 (char 0)
# Fetching page 42...
# Response status: 200
# Error fetching details for anime_id 3614: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 55150: Expecting value: line 1 column 1 (char 0)
# Fetching page 43...
# Response status: 200
# Error fetching details for anime_id 9959: Expecting value: line 1 column 1 (char 0)
# Fetching page 44...
# Response status: 200
# Error fetching details for anime_id 50175: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 1901: Expecting value: line 1 column 1 (char 0)
# Fetching page 45...
# Response status: 200
# Error fetching details for anime_id 2573: Expecting value: line 1 column 1 (char 0)
# Fetching page 46...
# Response status: 200
# Error fetching details for anime_id 40885: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 596: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 51585: Expecting value: line 1 column 1 (char 0)
# Fetching page 47...
# Response status: 200
# Fetching page 48...
# Response status: 200
# Error fetching details for anime_id 41341: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 56840: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 12321: Expecting value: line 1 column 1 (char 0)
# Fetching page 49...
# Response status: 200
# Fetching page 50...
# Response status: 200
# Error fetching details for anime_id 25719: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 507: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 13411: Expecting value: line 1 column 1 (char 0)
# Fetching page 51...
# Response status: 200
# Error fetching details for anime_id 59433: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 55842: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 41052: Expecting value: line 1 column 1 (char 0)
# Fetching page 52...
# Response status: 200
# Fetching page 53...
# Response status: 200
# Error fetching details for anime_id 42129: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 2122: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 54144: Expecting value: line 1 column 1 (char 0)
# Fetching page 54...
# Response status: 200
# Fetching page 55...
# Response status: 200
# Error fetching details for anime_id 33948: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 3807: Expecting value: line 1 column 1 (char 0)
# Error fetching details for anime_id 115: Expecting value: line 1 column 1 (char 0)
# Fetching page 56...
# Response status: 200
# Fetching page 57...
# Error fetching data: 504
# Anime data saved successfully! Total rows: 2494

# %%
print("Hello")
# Out:
# Hello

# %%
import json
import pandas as pd

# Load JSON data
json_filename = 'anime_data_2015_2025.json'
csv_filename = 'anime_data_2015_2025.csv'

with open(json_filename, 'r', encoding='utf-8') as f:
    anime_data = json.load(f)

# Convert JSON to DataFrame
df = pd.DataFrame(anime_data)

# Identify all columns that contain lists and convert them to comma-separated strings
for col in df.columns:
    if df[col].apply(lambda x: isinstance(x, list)).any():  # Check if any value in the column is a list
        df[col] = df[col].apply(lambda x: ', '.join(map(str, x)) if isinstance(x, list) else x)

# Save DataFrame as CSV (keeping the original JSON file)
df.to_csv(csv_filename, index=False, encoding='utf-8')

print(f"✅ JSON file '{json_filename}' is kept unchanged.")
print(f"✅ CSV file '{csv_filename}' created successfully!")
# Out:
# ✅ JSON file 'anime_data_2015_2025.json' is kept unchanged.
# ✅ CSV file 'anime_data_2015_2025.csv' created successfully!

# %%
#Display alll columns
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
anime_data= pd.read_csv("anime_data_2015_2025.csv")
anime_data.head()
# Out:
#    anime_id                               title  type  score  scored_by  \
# 0     52991                   Sousou no Frieren   NaN    NaN        NaN
# 1     60022                One Piece Fan Letter   NaN    NaN        NaN
# 2     38524  Shingeki no Kyojin Season 3 Part 2   NaN    NaN        NaN
# 3     28977                            Gintama°   NaN    NaN        NaN
# 4     39486                  Gintama: The Final   NaN    NaN        NaN
#
#             status  episodes  start_date    end_date  \
# 0  finished_airing       NaN  2023-09-29  2024-03-22
# 1  finished_airing       NaN  2024-10-20  2024-10-20
# 2  finished_airing       NaN  2019-04-29  2019-07-01
# 3  finished_airing       NaN  2015-04-08  2016-03-30
# 4  finished_airing       NaN  2021-01-08  2021-01-08
#
#                                               genres  \
# 0                 Adventure, Drama, Fantasy, Shounen
# 1                Action, Adventure, Fantasy, Shounen
# 2  Action, Drama, Gore, Military, Shounen, Surviv...
# 3  Action, Comedy, Gag Humor, Historical, Parody,...
# 4  Action, Comedy, Drama, Gag Humor, Historical, ...
#
#                                             synopsis  \
# 0  During their decade-long quest to defeat the D...
# 1  Although the golden age of piracy is about to ...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Gintoki, Shinpachi, and Kagura return as the f...
# 4  Two years have passed following the Tendoshuu'...
#
#                                         main_picture  url  title_english  \
# 0  https://cdn.myanimelist.net/images/anime/1015/...  NaN            NaN
# 1  https://cdn.myanimelist.net/images/anime/1455/...  NaN            NaN
# 2  https://cdn.myanimelist.net/images/anime/1517/...  NaN            NaN
# 3  https://cdn.myanimelist.net/images/anime/3/720...  NaN            NaN
# 4  https://cdn.myanimelist.net/images/anime/1245/...  NaN            NaN
#
#    title_japanese  title_synonyms  demographics                studios rating  \
# 0             NaN             NaN           NaN               Madhouse  pg_13
# 1             NaN             NaN           NaN         Toei Animation  pg_13
# 2             NaN             NaN           NaN             Wit Studio      r
# 3             NaN             NaN           NaN  Bandai Namco Pictures  pg_13
# 4             NaN             NaN           NaN  Bandai Namco Pictures  pg_13
#
#         source  rank  popularity  members  favorites
# 0        manga     1         164      NaN        NaN
# 1  light_novel     4        2426      NaN        NaN
# 2        manga     5          21      NaN        NaN
# 3        manga     6         343      NaN        NaN
# 4        manga     7        1537      NaN        NaN
